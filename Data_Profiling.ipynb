# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
import json
import pandas as pd

# %%
dataReview = []
with open('yelp_Fall2023/review.json') as f:
    for line in f:
        dataReview.append(json.loads(line))

f.close()

# %%
dataBusiness = []
with open('yelp_Fall2023/business.json') as f:
    for line in f:
        dataBusiness.append(json.loads(line))

f.close()

# %%
trips_data=pd.read_csv("yelp_Fall2023/Trips_by_Distance.csv")

# %%
trips_data.head()
# Out:
#       Level        Date  State FIPS State Postal Code  County FIPS  \
# 0  National  2019/01/01         NaN               NaN          NaN
# 1  National  2019/01/02         NaN               NaN          NaN
# 2  National  2019/01/03         NaN               NaN          NaN
# 3  National  2019/01/04         NaN               NaN          NaN
# 4  National  2019/01/05         NaN               NaN          NaN
#
#   County Name  Population Staying at Home  Population Not Staying at Home  \
# 0         NaN                  77433867.0                     248733553.0
# 1         NaN                  61305201.0                     264862219.0
# 2         NaN                  63050480.0                     263116940.0
# 3         NaN                  61803652.0                     264363768.0
# 4         NaN                  64389745.0                     261777675.0
#
#    Number of Trips  Number of Trips <1  ...  Number of Trips 5-10  \
# 0     8.977844e+08         241667151.0  ...           129670778.0
# 1     1.139452e+09         291276735.0  ...           171637514.0
# 2     1.162753e+09         296375014.0  ...           175775410.0
# 3     1.181954e+09         293159631.0  ...           181324645.0
# 4     1.180477e+09         295459014.0  ...           180941769.0
#
#    Number of Trips 10-25  Number of Trips 25-50  Number of Trips 50-100  \
# 0            116904343.0             40432062.0              15686639.0
# 1            167412698.0             56148976.0              17739183.0
# 2            172027487.0             57632422.0              18366626.0
# 3            176144493.0             58761592.0              19315785.0
# 4            165239790.0             54842134.0              19363939.0
#
#    Number of Trips 100-250  Number of Trips 250-500  Number of Trips >=500  \
# 0                7525563.0                1806022.0              1728112.0
# 1                7817044.0                1962301.0              1531219.0
# 2                8124548.0                2038099.0              1567072.0
# 3                8687318.0                2096065.0              1569185.0
# 4                8490791.0                1991159.0              1438664.0
#
#               Row ID  Week Month
# 0  00-00000-20190101     0     1
# 1  00-00000-20190102     0     1
# 2  00-00000-20190103     0     1
# 3  00-00000-20190104     0     1
# 4  00-00000-20190105     0     1
#
# [5 rows x 22 columns]

# %%
trips_data.loc[trips_data['State Postal Code']=='PA']['County Name'].unique()
# Out:
# array([nan, 'Adams County', 'Allegheny County', 'Armstrong County',
#        'Beaver County', 'Bedford County', 'Berks County', 'Blair County',
#        'Bradford County', 'Bucks County', 'Butler County',
#        'Cambria County', 'Cameron County', 'Carbon County',
#        'Centre County', 'Chester County', 'Clarion County',
#        'Clearfield County', 'Clinton County', 'Columbia County',
#        'Crawford County', 'Cumberland County', 'Dauphin County',
#        'Delaware County', 'Elk County', 'Erie County', 'Fayette County',
#        'Forest County', 'Franklin County', 'Fulton County',
#        'Greene County', 'Huntingdon County', 'Indiana County',
#        'Jefferson County', 'Juniata County', 'Lackawanna County',
#        'Lancaster County', 'Lawrence County', 'Lebanon County',
#        'Lehigh County', 'Luzerne County', 'Lycoming County',
#        'McKean County', 'Mercer County', 'Mifflin County',
#        'Monroe County', 'Montgomery County', 'Montour County',
#        'Northampton County', 'Northumberland County', 'Perry County',
#        'Philadelphia County', 'Pike County', 'Potter County',
#        'Schuylkill County', 'Snyder County', 'Somerset County',
#        'Sullivan County', 'Susquehanna County', 'Tioga County',
#        'Union County', 'Venango County', 'Warren County',
#        'Washington County', 'Wayne County', 'Westmoreland County',
#        'Wyoming County', 'York County'], dtype=object)

# %%
trips_data.loc[trips_data['State Postal Code']=='IN']['County Name'].unique()
# Out:
# array([nan, 'Whitley County', 'White County', 'Wells County',
#        'Wayne County', 'Washington County', 'Warrick County',
#        'Warren County', 'Wabash County', 'Vigo County',
#        'Vermillion County', 'Vanderburgh County', 'Union County',
#        'Tipton County', 'Tippecanoe County', 'Switzerland County',
#        'Sullivan County', 'Steuben County', 'Starke County',
#        'Spencer County', 'Shelby County', 'Scott County',
#        'St. Joseph County', 'Rush County', 'Ripley County',
#        'Randolph County', 'Putnam County', 'Pulaski County',
#        'Posey County', 'Porter County', 'Pike County', 'Perry County',
#        'Parke County', 'Owen County', 'Orange County', 'Ohio County',
#        'Noble County', 'Newton County', 'Morgan County',
#        'Montgomery County', 'Monroe County', 'Miami County',
#        'Martin County', 'Marshall County', 'Marion County',
#        'Madison County', 'Lawrence County', 'LaPorte County',
#        'Lake County', 'LaGrange County', 'Kosciusko County',
#        'Knox County', 'Johnson County', 'Jennings County',
#        'Jefferson County', 'Jay County', 'Jasper County',
#        'Jackson County', 'Huntington County', 'Howard County',
#        'Henry County', 'Hendricks County', 'Harrison County',
#        'Hancock County', 'Hamilton County', 'Greene County',
#        'Grant County', 'Gibson County', 'Fulton County',
#        'Franklin County', 'Fountain County', 'Floyd County',
#        'Fayette County', 'Elkhart County', 'Dubois County',
#        'Delaware County', 'DeKalb County', 'Decatur County',
#        'Dearborn County', 'Daviess County', 'Crawford County',
#        'Clinton County', 'Clay County', 'Clark County', 'Cass County',
#        'Carroll County', 'Brown County', 'Boone County',
#        'Blackford County', 'Benton County', 'Bartholomew County',
#        'Allen County', 'Adams County'], dtype=object)

# %%
# Converting the json data into a Pandas df
dataBusiness = pd.DataFrame(dataBusiness)
dataReview = pd.DataFrame(dataReview)

# Getting column names 
print(dataBusiness.columns)
print(dataReview.columns)
len(dataBusiness['name'].unique())
# Out:
# Index(['business_id', 'name', 'address', 'city', 'state', 'postal_code',
#        'latitude', 'longitude', 'stars', 'review_count', 'is_open',
#        'attributes', 'categories', 'hours'],
#       dtype='object')
# Index(['review_id', 'user_id', 'business_id', 'stars', 'useful', 'funny',
#        'cool', 'text', 'date'],
#       dtype='object')
# 114117

# %%
dataBusiness.loc[dataBusiness['business_id']=='Pns2l4eNsfO8kk83dixA6A']
# Out:
#               business_id                      name                 address  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ  1616 Chapala St, Ste 2
#
#             city state postal_code   latitude   longitude  stars  \
# 0  Santa Barbara    CA       93101  34.426679 -119.711197    5.0
#
#    review_count  is_open                     attributes  \
# 0             7        0  {'ByAppointmentOnly': 'True'}
#
#                                           categories hours
# 0  Doctors, Traditional Chinese Medicine, Naturop...  None

# %%
dataReview.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 1  BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ
# 2  saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
# 3  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 4  Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
#
#    stars  useful  funny  cool  \
# 0    3.0       0      0     0
# 1    5.0       1      0     1
# 2    3.0       0      0     0
# 3    5.0       1      0     1
# 4    4.0       1      0     1
#
#                                                 text                 date
# 0  If you decide to eat here, just be aware it is...  2018-07-07 22:09:11
# 1  I've taken a lot of spin classes over the year...  2012-01-03 15:28:18
# 2  Family diner. Had the buffet. Eclectic assortm...  2014-02-05 20:30:30
# 3  Wow!  Yummy, different,  delicious.   Our favo...  2015-01-04 00:01:03
# 4  Cute interior and owner (?) gave us tour of up...  2017-01-14 20:54:15

# %%
dataBusiness.columnss
# Out:
# Index(['business_id', 'name', 'address', 'city', 'state', 'postal_code',
#        'latitude', 'longitude', 'stars', 'review_count', 'is_open',
#        'attributes', 'categories', 'hours'],
#       dtype='object')

# %%
# Basic data descriptioin of Business Data 
dataBusiness.isnull().sum().sort_values(ascending=False)
# Out:
# hours           23223
# attributes      13744
# categories        103
# business_id         0
# name                0
# address             0
# city                0
# state               0
# postal_code         0
# latitude            0
# longitude           0
# stars               0
# review_count        0
# is_open             0
# dtype: int64

# %%
dataBusiness.city.value_counts()
# Out:
# Philadelphia      14569
# Tucson             9250
# Tampa              9050
# Indianapolis       7540
# Nashville          6971
#                   ...
# Gentilly              1
# pennsauken            1
# Hamiltion             1
# Newtown square        1
# Apollo beach          1
# Name: city, Length: 1416, dtype: int64

# %%
dataBusiness.categories
# Out:
# 0         Doctors, Traditional Chinese Medicine, Naturop...
# 1         Shipping Centers, Local Services, Notaries, Ma...
# 2         Department Stores, Shopping, Fashion, Home & G...
# 3         Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 4                                 Brewpubs, Breweries, Food
#                                 ...
# 150341                           Nail Salons, Beauty & Spas
# 150342    Pets, Nurseries & Gardening, Pet Stores, Hobby...
# 150343    Shopping, Jewelry, Piercing, Toy Stores, Beaut...
# 150344    Fitness/Exercise Equipment, Eyewear & Optician...
# 150345    Beauty & Spas, Permanent Makeup, Piercing, Tattoo
# Name: categories, Length: 150346, dtype: object

# %%
dataBusiness.dropna(subset=['categories'], inplace=True)
breweries = dataBusiness[dataBusiness.categories.str.contains("Brew")]

# %%
breweries.shape
# Out:
# (889, 14)

# %%
# keywords related to breweries
brewery_keywords = ['brewery', 'brewpub', 'breweries', 'brew house', 'alehouse', 'beer garden', 'beerhouse', 'biergarten']

# %%
# Use the str.contains() method with case insensitive search to filter the data
breweries_df = dataBusiness[dataBusiness['categories'].str.contains("Brew|Brewery|Brewpub|Breweries|Brew House|Alehouse|Beer Garden|Beerhouse|Biergarten", case=False, na=False)]

# %%
print(breweries_df)
# Out:
#                    business_id                          name  \
# 4       mWMc6_wTdE0EUBKIGXDVfA      Perkiomen Valley Brewery
# 35      aPNXGTDkf-4bjhyMBQxqpQ                    Craft Hall
# 81      7clCBgNbd-x2Wj96lZ6Mjw     Bier Brewery and Tap Room
# 112     sB45WFgysT617bKWP_WJwA  Budweiser Brewery Experience
# 389     cDekcTE1qwpz8ROlYixhqg   Philly Homebrew Outlet East
# ...                        ...                           ...
# 149821  ePQcZirx5-hZocoMs8aqNg             Eight & Sand Beer
# 150021  3BOurhEZ_kNhZ7Rrfpi0BA    Blackstone Brewing Company
# 150031  qiWD-qUrHYJ7xRHla68xiQ    Ram Restaurant & Brewhouse
# 150150  nTEmSvz8_DK-iK3miQFCwA           Great Basin Brewing
# 150198  lIZ2JghGs8dJ2HF85-3N0A    Swedesboro Brewing Company
#
#                      address          city state postal_code   latitude  \
# 4              101 Walnut St    Green Lane    PA       18054  40.338183
# 35        901 N Delaware Ave  Philadelphia    PA       19123  39.962582
# 81            5133 E 65th St  Indianapolis    IN       46220  39.875532
# 112            1200 Lynch St   Saint Louis    MO       63118  38.600197
# 389       1447 N American St  Philadelphia    PA       19122  39.973681
# ...                      ...           ...   ...         ...        ...
# 149821  1003 N Evergreen Ave      Woodbury    NJ       08096  39.849497
# 150021      2312 Clifton Ave     Nashville    TN       37209  36.158443
# 150031     12750 Parkside Dr       Fishers    IN       46038  39.973532
# 150150     846 Victorian Ave        Sparks    NV       89431  39.535095
# 150198       95 Woodstown Rd    Swedesboro    NJ       08085  39.733910
#
#          longitude  stars  review_count  is_open  \
# 4       -75.471659    4.5            13        1
# 35      -75.135657    3.5            65        1
# 81      -86.082857    4.5           139        1
# 112     -90.213538    4.5           605        1
# 389     -75.139648    5.0            32        0
# ...            ...    ...           ...      ...
# 149821  -75.142453    4.5            49        1
# 150021  -86.810201    4.5            36        1
# 150031  -86.002970    3.5           110        0
# 150150 -119.754133    4.0           580        1
# 150198  -75.318548    5.0             6        1
#
#                                                attributes  \
# 4       {'BusinessAcceptsCreditCards': 'True', 'Wheelc...
# 35      {'OutdoorSeating': 'True', 'RestaurantsPriceRa...
# 81      {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 112     {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 389     {'RestaurantsPriceRange2': '2', 'GoodForKids':...
# ...                                                   ...
# 149821  {'RestaurantsTakeOut': 'False', 'Caters': 'Fal...
# 150021  {'RestaurantsPriceRange2': '1', 'DogsAllowed':...
# 150031  {'NoiseLevel': 'u'average'', 'RestaurantsGoodF...
# 150150  {'RestaurantsPriceRange2': '2', 'BusinessAccep...
# 150198  {'RestaurantsTakeOut': 'True', 'RestaurantsDel...
#
#                                                categories  \
# 4                               Brewpubs, Breweries, Food
# 35      Eatertainment, Arts & Entertainment, Brewpubs,...
# 81                  Food, Beer, Wine & Spirits, Breweries
# 112     Bars, Beer Gardens, Food, Breweries, Nightlife...
# 389     Shopping, Food, Arts & Entertainment, Wholesal...
# ...                                                   ...
# 149821                                    Food, Breweries
# 150021                      Food, Local Flavor, Breweries
# 150031  American (New), Burgers, Breweries, Restaurant...
# 150150  Food, Bars, Restaurants, Brewpubs, Breweries, ...
# 150198                                    Food, Breweries
#
#                                                     hours
# 4       {'Wednesday': '14:0-22:0', 'Thursday': '16:0-2...
# 35      {'Monday': '0:0-0:0', 'Wednesday': '16:0-22:0'...
# 81      {'Tuesday': '15:0-21:0', 'Wednesday': '15:0-21...
# 112     {'Monday': '0:0-0:0', 'Tuesday': '9:0-17:0', '...
# 389     {'Monday': '11:0-19:0', 'Tuesday': '11:0-19:0'...
# ...                                                   ...
# 149821  {'Wednesday': '17:0-22:0', 'Thursday': '17:0-2...
# 150021  {'Monday': '16:0-20:0', 'Tuesday': '16:0-20:0'...
# 150031  {'Monday': '0:0-0:0', 'Tuesday': '11:0-22:0', ...
# 150150  {'Monday': '0:0-0:0', 'Tuesday': '11:0-21:0', ...
# 150198  {'Wednesday': '17:0-22:0', 'Thursday': '17:0-2...
#
# [1010 rows x 14 columns]

# %%
brewery_counts_by_city = breweries_df.groupby('city')['business_id'].nunique()


# Filter out cities with less than 10 breweries
brewery_counts_by_city = brewery_counts_by_city[brewery_counts_by_city >= 10]

# %%
brewery_counts_by_city_sorted = brewery_counts_by_city.sort_values(ascending=False)

# %%
# Plotting
plt.figure(figsize=(12, 8))  # Adjust the size of the figure as needed
brewery_counts_by_city_sorted.plot(kind='bar')

plt.title('Number of Breweries per City')
plt.xlabel('City')
plt.ylabel('Number of Breweries')
plt.xticks(rotation=45)  # Rotate the x labels so they don't overlap

# Show the plot
plt.tight_layout()  # Adjust the padding of the plot
plt.show()

# %%
## check whether has duplicated business id
breweries_df.business_id.duplicated().sum()
# Out:
# 0

# %%
breweries_df.isnull().sum()
# Out:
# business_id      0
# name             0
# address          0
# city             0
# state            0
# postal_code      0
# latitude         0
# longitude        0
# stars            0
# review_count     0
# is_open          0
# attributes       7
# categories       0
# hours           64
# dtype: int64

# %%
##  Checking the missing values from review data before merging 
dataReview.isnull().sum()
# Out:
# review_id      0
# user_id        0
# business_id    0
# stars          0
# useful         0
# funny          0
# cool           0
# text           0
# date           0
# dtype: int64

# %%
breweries_df_new=breweries_df[breweries_df['city'].isin(['Indianapolis', 'Philadelphia'])]

# %%
breweries_df_new.shape
# Out:
# (182, 14)

# %%
data_indi=breweries_df_new[breweries_df_new['city'] == 'Indianapolis']

# %%
data_philly=breweries_df_new[breweries_df_new['city'] == 'Philadelphia']

# %%
data_indi
# Out:
#                    business_id                               name  \
# 81      7clCBgNbd-x2Wj96lZ6Mjw          Bier Brewery and Tap Room
# 636     HCbJPXWXvwN-C7XfmVy3gA        Granite City Food & Brewery
# 3037    jnZYD2UCGziWwGsUxybkFw                     Daredevil Hall
# 3795    iHV3uBo1N9ETBtuEqdDsWQ              Sun King Broad Ripple
# 4673    JJNCJWaH2KV44r9aeEBlqA               Indiana City Brewing
# ...                        ...                                ...
# 140001  d87V_gH3I1EaGWOM_EYRXw          Books & Brews - Mass Ave.
# 142755  h0vaA8cPdjabzotwa6BsyA     Scarlet Lane Brewing Gastropub
# 144172  JydmOKf-8Plo13Idj33Iyw                 Round Town Brewery
# 145571  SYffIaST3GI1FNXk9A_uwg  Upland Brewing -  Fountain Square
# 149349  JpKKLxLo_6RxvQXyjVXnvQ                      Kuma's Corner
#
#                                            address          city state  \
# 81                                  5133 E 65th St  Indianapolis    IN
# 636                     49 W Maryland St, Ste B03A  Indianapolis    IN
# 3037                       2721 E 86th St, Ste 180  Indianapolis    IN
# 3795                         1021 Broad Ripple Ave  Indianapolis    IN
# 4673                                  24 Shelby St  Indianapolis    IN
# ...                                            ...           ...   ...
# 140001                       643 Massachusetts Ave  Indianapolis    IN
# 142755                       1702 Bellefontaine St  Indianapolis    IN
# 144172  950 S White River Parkway West Dr, Ste 100  Indianapolis    IN
# 145571                            1201 Prospect St  Indianapolis    IN
# 149349                            1127 Prospect St  Indianapolis    IN
#
#        postal_code   latitude  longitude  stars  review_count  is_open  \
# 81           46220  39.875532 -86.082857    4.5           139        1
# 636          46204  39.766420 -86.159245    3.5           258        0
# 3037         46240  39.911917 -86.118476    4.0           184        1
# 3795         46220  39.869321 -86.140748    4.0            97        0
# 4673         46202  39.765963 -86.141108    4.0           153        1
# ...            ...        ...        ...    ...           ...      ...
# 140001       46204  39.776012 -86.147293    3.5            28        0
# 142755       46202  39.790401 -86.142466    4.5           116        1
# 144172       46221  39.755351 -86.177004    4.5            37        0
# 145571       46203  39.751974 -86.138049    4.0           136        1
# 149349       46203  39.752186 -86.138780    4.0           628        1
#
#                                                attributes  \
# 81      {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 636     {'RestaurantsGoodForGroups': 'True', 'Ambience...
# 3037    {'RestaurantsTableService': 'True', 'Wheelchai...
# 3795    {'Smoking': 'u'no'', 'BusinessParking': '{'gar...
# 4673    {'BusinessAcceptsCreditCards': 'True', 'BikePa...
# ...                                                   ...
# 140001  {'BusinessParking': '{'garage': False, 'street...
# 142755  {'BusinessParking': '{'garage': False, 'street...
# 144172  {'RestaurantsPriceRange2': '1', 'BusinessParki...
# 145571  {'HasTV': 'True', 'HappyHour': 'False', 'ByApp...
# 149349  {'RestaurantsReservations': 'False', 'Restaura...
#
#                                                categories  \
# 81                  Food, Beer, Wine & Spirits, Breweries
# 636     Desserts, Breweries, Breakfast & Brunch, Resta...
# 3037    Brewpubs, Restaurants, Breweries, Beer Bar, Am...
# 3795    Food, Beer Bar, Pubs, Breweries, American (New...
# 4673                Breweries, Beer, Wine & Spirits, Food
# ...                                                   ...
# 140001  Used Bookstore, Brewpubs, Shopping, Breweries,...
# 142755  Restaurants, Salad, Gastropubs, Food, Brewerie...
# 144172                                    Food, Breweries
# 145571  Breweries, Brewpubs, Food, Bars, American (Tra...
# 149349  Burgers, Beer Gardens, American (Traditional),...
#
#                                                     hours
# 81      {'Tuesday': '15:0-21:0', 'Wednesday': '15:0-21...
# 636     {'Monday': '11:0-18:0', 'Tuesday': '11:0-0:0',...
# 3037    {'Tuesday': '16:0-21:0', 'Wednesday': '16:0-21...
# 3795    {'Monday': '0:0-0:0', 'Tuesday': '15:0-21:0', ...
# 4673    {'Wednesday': '16:0-20:0', 'Thursday': '16:0-2...
# ...                                                   ...
# 140001  {'Monday': '0:0-0:0', 'Tuesday': '11:0-22:0', ...
# 142755  {'Tuesday': '15:0-22:0', 'Wednesday': '15:0-22...
# 144172  {'Monday': '0:0-0:0', 'Tuesday': '16:0-21:0', ...
# 145571  {'Monday': '0:0-0:0', 'Tuesday': '11:0-22:0', ...
# 149349  {'Wednesday': '12:0-22:0', 'Thursday': '12:0-2...
#
# [82 rows x 14 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
data_indi['review_count_standard'] = scaler.fit_transform(data_indi[['review_count']])
# Out:
# /var/folders/1v/yzptk_9971x060dvwnyg9b240000gn/T/ipykernel_3823/3468476788.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_indi['review_count_standard'] = scaler.fit_transform(data_indi[['review_count']])

# %%
data_indi.head()
# Out:
#                  business_id                         name  \
# 81    7clCBgNbd-x2Wj96lZ6Mjw    Bier Brewery and Tap Room
# 636   HCbJPXWXvwN-C7XfmVy3gA  Granite City Food & Brewery
# 3037  jnZYD2UCGziWwGsUxybkFw               Daredevil Hall
# 3795  iHV3uBo1N9ETBtuEqdDsWQ        Sun King Broad Ripple
# 4673  JJNCJWaH2KV44r9aeEBlqA         Indiana City Brewing
#
#                          address          city state postal_code   latitude  \
# 81                5133 E 65th St  Indianapolis    IN       46220  39.875532
# 636   49 W Maryland St, Ste B03A  Indianapolis    IN       46204  39.766420
# 3037     2721 E 86th St, Ste 180  Indianapolis    IN       46240  39.911917
# 3795       1021 Broad Ripple Ave  Indianapolis    IN       46220  39.869321
# 4673                24 Shelby St  Indianapolis    IN       46202  39.765963
#
#       longitude  stars  review_count  is_open  \
# 81   -86.082857    4.5           139        1
# 636  -86.159245    3.5           258        0
# 3037 -86.118476    4.0           184        1
# 3795 -86.140748    4.0            97        0
# 4673 -86.141108    4.0           153        1
#
#                                              attributes  \
# 81    {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 636   {'RestaurantsGoodForGroups': 'True', 'Ambience...
# 3037  {'RestaurantsTableService': 'True', 'Wheelchai...
# 3795  {'Smoking': 'u'no'', 'BusinessParking': '{'gar...
# 4673  {'BusinessAcceptsCreditCards': 'True', 'BikePa...
#
#                                              categories  \
# 81                Food, Beer, Wine & Spirits, Breweries
# 636   Desserts, Breweries, Breakfast & Brunch, Resta...
# 3037  Brewpubs, Restaurants, Breweries, Beer Bar, Am...
# 3795  Food, Beer Bar, Pubs, Breweries, American (New...
# 4673              Breweries, Beer, Wine & Spirits, Food
#
#                                                   hours  review_count_standard
# 81    {'Tuesday': '15:0-21:0', 'Wednesday': '15:0-21...               0.215088
# 636   {'Monday': '11:0-18:0', 'Tuesday': '11:0-0:0',...               0.406100
# 3037  {'Tuesday': '16:0-21:0', 'Wednesday': '16:0-21...               0.287319
# 3795  {'Monday': '0:0-0:0', 'Tuesday': '15:0-21:0', ...               0.147673
# 4673  {'Wednesday': '16:0-20:0', 'Thursday': '16:0-2...               0.237560

# %%
data_philly['review_count_standard'] = scaler.fit_transform(data_philly[['review_count']])
# Out:
# /var/folders/1v/yzptk_9971x060dvwnyg9b240000gn/T/ipykernel_3823/1655953440.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_philly['review_count_standard'] = scaler.fit_transform(data_philly[['review_count']])

# %%
data_philly.head()
# Out:
#                  business_id                              name  \
# 35    aPNXGTDkf-4bjhyMBQxqpQ                        Craft Hall
# 389   cDekcTE1qwpz8ROlYixhqg       Philly Homebrew Outlet East
# 1106  NQSnr4RPUScss607oxOaqw                  Chase's Hop Shop
# 3253  ShYwqkUf7PkI7LHqCyTmEA  PHS Pop Up Garden - uCity Square
# 4306  dO4iyNK2KzLMe1kXLCskbw                 St. Declan's Well
#
#                   address          city state postal_code   latitude  \
# 35     901 N Delaware Ave  Philadelphia    PA       19123  39.962582
# 389    1447 N American St  Philadelphia    PA       19122  39.973681
# 1106  7235 Rising Sun Ave  Philadelphia    PA       19111  40.060386
# 3253    36th & Filbert St  Philadelphia    PA       19104  39.957088
# 4306       3131 Walnut St  Philadelphia    PA       19104  39.952126
#
#       longitude  stars  review_count  is_open  \
# 35   -75.135657    3.5            65        1
# 389  -75.139648    5.0            32        0
# 1106 -75.084590    4.5           116        1
# 3253 -75.194128    4.0            13        0
# 4306 -75.186438    3.5            30        0
#
#                                              attributes  \
# 35    {'OutdoorSeating': 'True', 'RestaurantsPriceRa...
# 389   {'RestaurantsPriceRange2': '2', 'GoodForKids':...
# 1106  {'RestaurantsReservations': 'False', 'Alcohol'...
# 3253  {'Alcohol': 'u'full_bar'', 'RestaurantsPriceRa...
# 4306  {'OutdoorSeating': 'False', 'WiFi': 'u'free'',...
#
#                                              categories  \
# 35    Eatertainment, Arts & Entertainment, Brewpubs,...
# 389   Shopping, Food, Arts & Entertainment, Wholesal...
# 1106  Chicken Wings, Nightlife, Bars, Delis, Food, B...
# 3253                            Beer Gardens, Nightlife
# 4306  Nightlife, Music Venues, Irish, Pubs, Irish Pu...
#
#                                                   hours  review_count_standard
# 35    {'Monday': '0:0-0:0', 'Wednesday': '16:0-22:0'...               0.053763
# 389   {'Monday': '11:0-19:0', 'Tuesday': '11:0-19:0'...               0.024194
# 1106  {'Monday': '0:0-0:0', 'Tuesday': '13:15-20:30'...               0.099462
# 3253  {'Monday': '16:0-21:0', 'Tuesday': '16:0-21:0'...               0.007168
# 4306  {'Monday': '11:0-2:0', 'Tuesday': '11:0-2:0', ...               0.022401

# %%
## merge business table and review table
indi_breweries_review = pd.merge(data_indi, dataReview, on = 'business_id')

# %%
indi_breweries_review.shape
# Out:
# (13364, 23)

# %%
philly_breweries_review = pd.merge(data_philly, dataReview, on = 'business_id')

# %% [markdown]
# ### Choosing the two cities with maximum Breweries in our use case its Indianapolis and Philadelphia

# %%
df_filtered.shape
# Out:
# (28411, 22)

# %%
df_filtered['business_id'].nunique()
# Out:
# 182

# %% [markdown]
# ### Given we have 182 breweries in our data set Indianapolis : 82 , Philadelphia : 100

# %% [markdown]
# ####  Way to visualise the review count first based on cities and then individually in someway so it make sense and can be used for certain analysis

# %%
## update column names
indi_breweries_review.rename(columns={'stars_x':'avg_star','stars_y':'review_star'}, inplace=True)

## add column of number of words in review and label of negative and postive reviews
indi_breweries_review['num_words_review'] = df_filtered.text.str.replace('\n',''). \
                                          str.replace('[!"#$%&\()*+,-./:;<=>?@[\\]^_`{|}~]','').map(lambda x: len(x.split()))
# Out:
# /var/folders/1v/yzptk_9971x060dvwnyg9b240000gn/T/ipykernel_3823/2638943133.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   indi_breweries_review['num_words_review'] = df_filtered.text.str.replace('\n',''). \

# %%
## update column names
philly_breweries_review.rename(columns={'stars_x':'avg_star','stars_y':'review_star'}, inplace=True)

## add column of number of words in review and label of negative and postive reviews
philly_breweries_review['num_words_review'] = df_filtered.text.str.replace('\n',''). \
                                          str.replace('[!"#$%&\()*+,-./:;<=>?@[\\]^_`{|}~]','').map(lambda x: len(x.split()))
# Out:
# /var/folders/1v/yzptk_9971x060dvwnyg9b240000gn/T/ipykernel_3823/3589495186.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   philly_breweries_review['num_words_review'] = df_filtered.text.str.replace('\n',''). \

# %%
indi_breweries_review.reset_index()
philly_breweries_review.reset_index()
# Out:
#        index             business_id              name             address  \
# 0          0  aPNXGTDkf-4bjhyMBQxqpQ        Craft Hall  901 N Delaware Ave
# 1          1  aPNXGTDkf-4bjhyMBQxqpQ        Craft Hall  901 N Delaware Ave
# 2          2  aPNXGTDkf-4bjhyMBQxqpQ        Craft Hall  901 N Delaware Ave
# 3          3  aPNXGTDkf-4bjhyMBQxqpQ        Craft Hall  901 N Delaware Ave
# 4          4  aPNXGTDkf-4bjhyMBQxqpQ        Craft Hall  901 N Delaware Ave
# ...      ...                     ...               ...                 ...
# 15042  15042  P0LuuY4gbVRWhUQ1wa6BrA  Fishtown Brewpub  1101 Frankford Ave
# 15043  15043  P0LuuY4gbVRWhUQ1wa6BrA  Fishtown Brewpub  1101 Frankford Ave
# 15044  15044  P0LuuY4gbVRWhUQ1wa6BrA  Fishtown Brewpub  1101 Frankford Ave
# 15045  15045  P0LuuY4gbVRWhUQ1wa6BrA  Fishtown Brewpub  1101 Frankford Ave
# 15046  15046  P0LuuY4gbVRWhUQ1wa6BrA  Fishtown Brewpub  1101 Frankford Ave
#
#                city state postal_code   latitude  longitude  avg_star  ...  \
# 0      Philadelphia    PA       19123  39.962582 -75.135657       3.5  ...
# 1      Philadelphia    PA       19123  39.962582 -75.135657       3.5  ...
# 2      Philadelphia    PA       19123  39.962582 -75.135657       3.5  ...
# 3      Philadelphia    PA       19123  39.962582 -75.135657       3.5  ...
# 4      Philadelphia    PA       19123  39.962582 -75.135657       3.5  ...
# ...             ...   ...         ...        ...        ...       ...  ...
# 15042  Philadelphia    PA       19125  39.967725 -75.134025       3.5  ...
# 15043  Philadelphia    PA       19125  39.967725 -75.134025       3.5  ...
# 15044  Philadelphia    PA       19125  39.967725 -75.134025       3.5  ...
# 15045  Philadelphia    PA       19125  39.967725 -75.134025       3.5  ...
# 15046  Philadelphia    PA       19125  39.967725 -75.134025       3.5  ...
#
#        review_count_standard               review_id                 user_id  \
# 0                   0.053763  sQMYwwfj5tggxisUZXwgkA  KGEdaKlPI-Sv2K_pa2HKgg
# 1                   0.053763  c09IhAED9khTlK1Nw4Wf9A  kauJmG3ZiA-m5u0nPrjb4g
# 2                   0.053763  1FIFzSnwuyGw0V0a75-1Nw  i8FUZZFocxs24W9FYrGRDQ
# 3                   0.053763  5-YovLQWy6Srq0UnTdVhuw  BqJWbbmEiefT9c4u9Nj8BQ
# 4                   0.053763  M-38wpRyPVRT35MgRmLCjQ  Ddd0ZKIFQd_NYqclMXYFKw
# ...                      ...                     ...                     ...
# 15042               0.080645  Vx76HCmIKJgpL_ju3qDP9w  ET8n-r7glWYqZhuR6GcdNw
# 15043               0.080645  yjpuDZGJxft5mkfeJvcyHA  0RX9w878R80Ok5iPrNBv3g
# 15044               0.080645  aojbR0b7oxc4-p3VkLLKqA  _T7ZInXEP0MxIqsQx0IhhQ
# 15045               0.080645  Y9XLltKokSXMRybBq-9EAw  q-gbZrtxbSb7r-EJIqAXFA
# 15046               0.080645  -p2WJNvyC0-w8HGYBOQeng  rvYTWj_twMGMkT3k7qjxZQ
#
#       review_star useful  funny cool  \
# 0             4.0      0      0    0
# 1             3.0      2      0    1
# 2             5.0      0      0    0
# 3             5.0      0      0    0
# 4             5.0      0      0    0
# ...           ...    ...    ...  ...
# 15042         2.0     26      3    6
# 15043         5.0      0      0    0
# 15044         3.0      1      0    0
# 15045         4.0      1      0    2
# 15046         4.0      3      0    0
#
#                                                     text                 date  \
# 0      This is a great place to take guests visiting ...  2019-07-22 22:48:30
# 1      As a bar, this place has almost everything you...  2019-06-25 15:55:26
# 2      First time here and it is great! Huge open spa...  2019-03-29 23:11:14
# 3      Awesome place for families with kids under 8. ...  2019-04-13 18:44:14
# 4      The BEST new addition, especially for families...  2019-05-13 01:56:25
# ...                                                  ...                  ...
# 15042  My experience at Fishtown Brewpub last weekend...  2017-08-28 16:23:08
# 15043  This past Sunday we stopped at Fishtown Brewpu...  2018-07-25 12:56:14
# 15044  Place is nice, clean . Service could be a litt...  2017-10-14 05:38:04
# 15045  Stopped here with some friends, place was kind...  2019-03-21 23:10:18
# 15046  I came in to Fishtown Brewpub with a large gro...  2017-09-05 02:25:09
#
#        num_words_review
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 15042             194.0
# 15043             282.0
# 15044             154.0
# 15045             329.0
# 15046              54.0
#
# [15047 rows x 25 columns]

# %%
import ast

# Function to convert string representation of a dictionary to a dictionary
def str_to_dict(s):
    try:
        return ast.literal_eval(s)
    except ValueError:
        return s

# %%
philly_breweries_review['attributes'] = philly_breweries_review['attributes'].apply(str_to_dict)
indi_breweries_review['attributes'] = indi_breweries_review['attributes'].apply(str_to_dict)
# Out:
# /var/folders/1v/yzptk_9971x060dvwnyg9b240000gn/T/ipykernel_3823/743064579.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['attributes'] = df_filtered['attributes'].apply(str_to_dict)

# %%
indi_attributes_expanded = indi_breweries_review['attributes'].apply(pd.Series)


indi_df_final = indi_breweries_review.drop('attributes', axis=1).join(philly_attributes_expanded)


print(indi_df_final.shape)
# Out:
# (13364, 56)

# %%
philly_attributes_expanded = philly_breweries_review['attributes'].apply(pd.Series)


philly_df_final = philly_breweries_review.drop('attributes', axis=1).join(philly_attributes_expanded)


print(philly_df_final.shape)
# Out:
# /var/folders/1v/yzptk_9971x060dvwnyg9b240000gn/T/ipykernel_3823/1675868030.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   philly_attributes_expanded = philly_breweries_review['attributes'].apply(pd.Series)
# /var/folders/1v/yzptk_9971x060dvwnyg9b240000gn/T/ipykernel_3823/1675868030.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   philly_attributes_expanded = philly_breweries_review['attributes'].apply(pd.Series)
# /var/folders/1v/yzptk_9971x060dvwnyg9b240000gn/T/ipykernel_3823/1675868030.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   philly_attributes_expanded = philly_breweries_review['attributes'].apply(pd.Series)
# /var/folders/1v/yzptk_9971x060dvwnyg9b240000gn/T/ipykernel_3823/1675868030.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   philly_attributes_expanded = philly_breweries_review['attributes'].apply(pd.Series)
# /var/folders/1v/yzptk_9971x060dvwnyg9b240000gn/T/ipykernel_3823/1675868030.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   philly_attributes_expanded = philly_breweries_review['attributes'].apply(pd.Series)
# /var/folders/1v/yzptk_9971x060dvwnyg9b240000gn/T/ipykernel_3823/1675868030.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   philly_attributes_expanded = philly_breweries_review['attributes'].apply(pd.Series)
# /var/folders/1v/yzptk_9971x060dvwnyg9b240000gn/T/ipykernel_3823/1675868030.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   philly_attributes_expanded = philly_breweries_review['attributes'].apply(pd.Series)
# /var/folders/1v/yzptk_9971x060dvwnyg9b240000gn/T/ipykernel_3823/1675868030.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   philly_attributes_expanded = philly_breweries_review['attributes'].apply(pd.Series)
# /var/folders/1v/yzptk_9971x060dvwnyg9b240000gn/T/ipykernel_3823/1675868030.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   philly_attributes_expanded = philly_breweries_review['attributes'].apply(pd.Series)
# /var/folders/1v/yzptk_9971x060dvwnyg9b240000gn/T/ipykernel_3823/1675868030.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   philly_attributes_expanded = philly_breweries_review['attributes'].apply(pd.Series)
# /var/folders/1v/yzptk_9971x060dvwnyg9b240000gn/T/ipykernel_3823/1675868030.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   philly_attributes_expanded = philly_breweries_review['attributes'].apply(pd.Series)
# /var/folders/1v/yzptk_9971x060dvwnyg9b240000gn/T/ipykernel_3823/1675868030.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   philly_attributes_expanded = philly_breweries_review['attributes'].apply(pd.Series)
# /var/folders/1v/yzptk_9971x060dvwnyg9b240000gn/T/ipykernel_3823/1675868030.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   philly_attributes_expanded = philly_breweries_review['attributes'].apply(pd.Series)
# /var/folders/1v/yzptk_9971x060dvwnyg9b240000gn/T/ipykernel_3823/1675868030.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   philly_attributes_expanded = philly_breweries_review['attributes'].apply(pd.Series)
# (15047, 56)

# %%
indi_df_final.to_csv('indi_beer_data.csv')
philly_df_final.to_csv('philly_beer_data.csv')
